# %% [markdown]
# <a href="https://colab.research.google.com/github/rromerov/Proyecto_Integrador/blob/main/Avance1/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instituto Tecnológico y de Estudios Superiores de Monterrey
# ## Maestría en Inteligencia Artificial Aplicada
# ### Proyecto Integrador (Gpo 10) - TC5035.10
#
# ### **Proyecto: Diseño Acelerado de Fármacos**
#
# ### Avance 1: Análisis exploratorio de datos
#
# #### **Docentes:**
# - Dra. Grettel Barceló Alonso - Profesor Titular
# - Dr. Luis Eduardo Falcón Morales - Profesor Titular
# - Dr. Ricardo Ambrocio Ramírez Mendoza  – Profesor Tutor
#
# #### **Miembros del equipo:**
# - Ernesto Enríquez Rubio - A01228409
# - Roberto Romero Vielma - A00822314
# - Herbert Joadan Romero Villarreal –  A01794199

# %% [markdown]
# # Análisis exploratorio de los datos

# %% [markdown]
# ## Instalar librerias faltantes

# %%
! pip install chembl_webresource_client
! pip install --extra-index-url=https://pypi.nvidia.com cudf-cu12
! pip install rdkit
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 829.9 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.11.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-23.2.3 chembl_webresource_client-0.10.9 requests-cache-1.2.0 url-normalize-1.4.3
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cudf-cu12
#   Downloading https://pypi.nvidia.com/cudf-cu12/cudf_cu12-24.4.1-cp310-cp310-manylinux_2_28_x86_64.whl (473.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.3/473.3 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (5.3.3)
# Collecting cuda-python<13.0a0,>=12.0 (from cudf-cu12)
#   Downloading cuda_python-12.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: cupy-cuda12x>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (12.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (2023.6.0)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (0.58.1)
# Requirement already satisfied: numpy<2.0a0,>=1.23 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (1.25.2)
# Collecting nvtx>=0.2.1 (from cudf-cu12)
#   Downloading nvtx-0.2.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.6/582.6 kB 33.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (24.0)
# Requirement already satisfied: pandas<2.2.2dev0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (2.0.3)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (3.20.3)
# Collecting pynvjitlink-cu12 (from cudf-cu12)
#   Downloading https://pypi.nvidia.com/pynvjitlink-cu12/pynvjitlink_cu12-0.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<15.0.0a0,>=14.0.1 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (14.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (13.7.1)
# Collecting rmm-cu12==24.4.* (from cudf-cu12)
#   Downloading https://pypi.nvidia.com/rmm-cu12/rmm_cu12-24.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.9 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cudf-cu12) (4.11.0)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x>=12.0.0->cudf-cu12) (0.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.57->cudf-cu12) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.2dev0,>=2.0->cudf-cu12) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.2dev0,>=2.0->cudf-cu12) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.2dev0,>=2.0->cudf-cu12) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->cudf-cu12) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->cudf-cu12) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->cudf-cu12) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.2.2dev0,>=2.0->cudf-cu12) (1.16.0)
# Installing collected packages: nvtx, cuda-python, pynvjitlink-cu12, rmm-cu12, cudf-cu12
# Successfully installed cuda-python-12.4.0 cudf-cu12-24.4.1 nvtx-0.2.10 pynvjitlink-cu12-0.2.3 rmm-cu12-24.4.0
# Collecting rdkit
#   Downloading rdkit-2023.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.6

# %% [markdown]
# ## Importar librerias

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
from google.colab import drive
import locale
import sys
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu

# %% [markdown]
# **Compuestos inhibidores de la proteina VEFG**
#
# * Pazopanib: Es un inhibidor multiquinasa con biodisponibilidad oral. Actúa sobre los tres tipos de receptores del factor de crecimiento vascular endotelial (VEGFR-1, VEGFR-2 y VEGFR-3),
# * Sunitinib: Actúa bloqueando los receptores del factor de crecimiento derivado de plaquetas (PDGFRα y PDGFRβ), los receptores VEGF (VEGFR1, VEGFR2 y VEGFR3), el receptor de factor de células madre (KIT), la tirosin-quinasa 3 tipo Fms (FLT3), el factor estimulador de colonias (CSF-1R) y el receptor del factor de crecimiento epidérmico (EGFR).
# * Bevacizumab: Al unirse al VEGF, bevacizumab inhibe su unión a los receptores Flt-1 (VEGFR-1) y KDR (VEGFR-2) presentes en la superficie de las células endoteliales.
# * Sorafenib:  Inhibe varios receptores de factores de crecimiento, como las kinasas de tirosina. Algunos de estos receptores incluyen:
# PDGFR-beta,VEGFR-2 (receptor 2 del factor de crecimiento endotelial vascular), VEGFR-3
# * Regorafenib:  Afecta a múltiples quinasas, incluyendo aquellas involucradas en la angiogénesis, mientras que el VEGF 165 desempeña un papel crítico en la promoción de la formación de vasos sanguíneos.
# * Cabozantinib: cabozantinib actúa como un inhibidor de VEGF y MET, lo que lo convierte en una opción terapéutica para ciertos tipos de cáncer.
# * Lenvatinib: Se dirige selectivamente a la actividad quinasa de varios receptores, incluyendo los del factor de crecimiento del endotelio vascular (VEGF): VEGFR1 (FLT1), VEGFR2 (KDR) y VEGFR3 (FLT4).

# %% [markdown]
# # ChEMBL IDs

# %%
# ChEMBL IDs
drugs_for_vegf_protein_ids = {
    'pazopanib': 'CHEMBL477772',
    'sunitinib': 'CHEMBL535',
    # 'bevacizumab': 'CHEMBL1201583',
    'sorafenib': 'CHEMBL1336',
    'regorafenib': 'CHEMBL1946170',
    'cabozantinib': 'CHEMBL2105717',
    'lenvatinib': 'CHEMBL1289601',
    'vandetanib': 'CHEMBL24828',
    'axitinib' :'CHEMBL1289926',
    'foretinib': 'CHEMBL1230609',
    'tivozanib': 'CHEMBL1289494',
    'dovitinib': 'CHEMBL522892',
    'orantinib': 'CHEMBL274654',
    'nintedanib': 'CHEMBL502835',
    'vatalanib': 'CHEMBL101253',
    'telatinib': 'CHEMBL2079588',
    'motesanib': 'CHEMBL572881',
    'brivanib': 'CHEMBL377300',
    'linifanib': 'CHEMBL223360',
    'regorafenib': 'CHEMBL1946170'}

# %%
# Obtener información molecular
molecule = new_client.molecule
drugs_can_smiles = {}
for drug_name, drug_chembl in drugs_for_vegf_protein_ids.items():
    drugs_can_smiles.update({drug_name: molecule.get(drug_chembl).get('molecule_structures').get('canonical_smiles')})
    # Print out the results
    print(drug_name, ' > ', drugs_can_smiles[drug_name])
# Out:
# pazopanib  >  Cc1ccc(Nc2nccc(N(C)c3ccc4c(C)n(C)nc4c3)n2)cc1S(N)(=O)=O
# sunitinib  >  CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C
# sorafenib  >  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1
# regorafenib  >  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)c(F)c2)ccn1
# cabozantinib  >  COc1cc2nccc(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3)c2cc1OC
# lenvatinib  >  COc1cc2nccc(Oc3ccc(NC(=O)NC4CC4)c(Cl)c3)c2cc1C(N)=O
# vandetanib  >  COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1
# axitinib  >  CNC(=O)c1ccccc1Sc1ccc2c(/C=C/c3ccccn3)n[nH]c2c1
# foretinib  >  COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1
# tivozanib  >  COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c2cc1OC
# dovitinib  >  CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1
# orantinib  >  Cc1[nH]c(/C=C2\C(=O)Nc3ccccc32)c(C)c1CCC(=O)O
# nintedanib  >  COC(=O)c1ccc2c(c1)NC(=O)/C2=C(\Nc1ccc(N(C)C(=O)CN2CCN(C)CC2)cc1)c1ccccc1
# vatalanib  >  Clc1ccc(Nc2nnc(Cc3ccncc3)c3ccccc23)cc1
# telatinib  >  CNC(=O)c1cc(COc2nnc(Nc3ccc(Cl)cc3)c3ccoc23)ccn1
# motesanib  >  CC1(C)CNc2cc(NC(=O)c3cccnc3NCc3ccncc3)ccc21
# brivanib  >  Cc1cc2c(F)c(Oc3ncnn4cc(OC[C@@H](C)O)c(C)c34)ccc2[nH]1
# linifanib  >  Cc1ccc(F)c(NC(=O)Nc2ccc(-c3cccc4[nH]nc(N)c34)cc2)c1

# %% [markdown]
# # Inhibidores del receptor del factor de crecimiento endotelial vascular

# %%
# Accede al atributo 'mechanism'
mechanism_client = new_client.mechanism

# Busca el ID del mecanismo "Vascular endothelial growth factor receptor inhibitor"
# Si no conoces el ID de antemano, puedes buscarlo filtrando por mecanismo de acción
mechanism_name = 'Vascular endothelial growth factor receptor inhibitor'
mechanism_info = mechanism_client.filter(mechanism_of_action=mechanism_name)

# %%
# Obtener los compuestos ChMBL que son inhibidores
inhi_chmbl_ids = [mechanism_info[i]['molecule_chembl_id'] for i in range(len(mechanism_info))]

# %%
# Obtener información molecular
molecule = new_client.molecule
drugs_can_smiles = {}
for drug_chembl in inhi_chmbl_ids:
    try:
      molecule_chembl = molecule.get(drug_chembl)
      molecule_structure = molecule_chembl.get('molecule_structures')
      molecule_canon_smiles = molecule_structure.get('canonical_smiles')
      molecule_name = molecule_structure.get('molfile').split('\n')[-1].lower()
      drugs_can_smiles.update({molecule_name: molecule_canon_smiles})
      # Print out the results
      print(molecule_name, ' > ', drugs_can_smiles[molecule_name])
    except:
      print(f'Compuesto {drug_chembl} no fue encontrado.')
# Out:
# sunitinib malate  >  CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c1C.O=C(O)C[C@H](O)C(=O)O
# axitinib  >  CNC(=O)c1ccccc1Sc1ccc2c(/C=C/c3ccccn3)n[nH]c2c1
# vandetanib  >  COc1cc2/c(=N/c3ccc(Br)cc3F)nc[nH]c2cc1OCC1CCN(C)CC1
# sorafenib tosylate  >  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1.Cc1ccc(S(=O)(=O)O)cc1
# pazopanib hydrochloride  >  Cc1ccc(Nc2nccc(N(C)c3ccc4c(C)n(C)nc4c3)n2)cc1S(N)(=O)=O.Cl
# regorafenib  >  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)c(F)c2)ccn1
# nintedanib esylate  >  CCS(=O)(=O)O.COC(=O)c1ccc2c(c1)NC(=O)/C2=C(\Nc1ccc(N(C)C(=O)CN2CCN(C)CC2)cc1)c1ccccc1
# lenvatinib mesylate  >  COc1cc2nccc(Oc3ccc(NC(=O)NC4CC4)c(Cl)c3)c2cc1C(N)=O.CS(=O)(=O)O
# su-014813  >  Cc1[nH]c(/C=C2\C(=O)Nc3ccc(F)cc32)c(C)c1C(=O)NC[C@H](O)CN1CCOCC1
# 4sc-203  >  COc1ccc(C)cc1NC(=O)Nc1nc2ccc(Nc3ncnc4cc(OCCCN5CCN(C)CC5)c(OC)cc34)cc2s1
# ilorasertib  >  Nc1ncc(-c2cnn(CCO)c2)c2scc(-c3ccc(NC(=O)Nc4cccc(F)c4)cc3)c12
# cep-11981  >  CC(C)Cn1c2ccc(Nc3ncccn3)cc2c2c3c(c4c(c21)CCc1nn(C)cc1-4)C(=O)NC3
# cep-5214  >  CC(C)OCc1ccc2c(c1)c1c3c(c4c(c1n2CCCO)Cc1ccccc1-4)C(=O)NC3
# cep-7055  >  CC(C)OCc1ccc2c(c1)c1c3c(c4c(c1n2CCCOC(=O)CN(C)C)Cc1ccccc1-4)C(=O)NC3
# Compuesto CHEMBL3545300 no fue encontrado.
# ibcasertib  >  COc1ccc2c(Oc3ccc4c(C(=O)Nc5ccccc5N)cccc4c3)ccnc2c1
# surufatinib  >  Cc1cc2cc(Oc3ccnc(Nc4cccc(CS(=O)(=O)NCCN(C)C)c4)n3)ccc2[nH]1
# krn-633  >  CCCNC(=O)Nc1ccc(Oc2ncnc3cc(OC)c(OC)cc23)cc1Cl
# l-21649  >  c1cc(-c2cnn3cc(-c4ccc(OCCN5CCCCC5)cc4)cnc23)cs1
# osi-930  >  O=C(Nc1ccc(OC(F)(F)F)cc1)c1sccc1NCc1ccnc2ccccc12
# tak-593  >  Cc1cc(C(=O)Nc2cc(Oc3ccc4nc(NC(=O)C5CC5)cn4n3)ccc2C)n(C)n1
# rg-1530  >  COc1cc2c(cc1F)C(c1ccccc1Cl)=Nc1c(n[nH]c1C)N2
# ag-13958  >  Cc1cc(C(=O)Nc2cc(Nc3ccc4c(/C=C/c5ccccn5)n[nH]c4c3)ccc2F)n(C)n1
# bms-690514  >  COc1cccc(Nc2ncnn3ccc(CN4CC[C@@H](N)[C@H](O)C4)c23)c1
# lucitanib  >  CNC(=O)c1cccc2cc(Oc3ccnc4cc(OCC5(N)CC5)c(OC)cc34)ccc12
# foretinib  >  COc1cc2c(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3F)ccnc2cc1OCCCN1CCOCC1
# fruquintinib  >  CNC(=O)c1c(C)oc2cc(Oc3ncnc4cc(OC)c(OC)cc34)ccc12
# Compuesto CHEMBL3545401 no fue encontrado.
# Compuesto CHEMBL3545402 no fue encontrado.
# xl-999  >  CCN1CCC(Nc2ccc3c(c2)/C(=C(\c2cccc(F)c2)c2nc(C)c[nH]2)C(=O)N3)CC1
# linifanib  >  Cc1ccc(F)c(NC(=O)Nc2ccc(-c3cccc4[nH]nc(N)c34)cc2)c1
# cediranib  >  COc1cc2c(Oc3ccc4[nH]c(C)cc4c3F)ncnc2cc1OCCCN1CCCC1
# brivanib  >  Cc1cc2c(F)c(Oc3ncnn4cc(OC[C@@H](C)O)c(C)c34)ccc2[nH]1
# brivanib alaninate  >  Cc1cc2c(F)c(Oc3ncnn4cc(OC[C@@H](C)OC(=O)[C@H](C)N)c(C)c34)ccc2[nH]1
# tivozanib  >  COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c2cc1OC
# vatalanib  >  Clc1ccc(Nc2nnc(Cc3ccncc3)c3ccccc23)cc1
# semaxanib  >  Cc1cc(C)c(/C=C2\C(=O)Nc3ccccc32)[nH]1
# dovitinib  >  CN1CCN(c2ccc3nc(-c4c(N)c5c(F)cccc5[nH]c4=O)[nH]c3c2)CC1
# motesanib  >  CC1(C)CNc2cc(NC(=O)c3cccnc3NCc3ccncc3)ccc21
# glesatinib  >  COCCNCc1ccc(-c2cc3nccc(Oc4ccc(NC(=S)NC(=O)Cc5ccc(F)cc5)cc4F)c3s2)nc1
# tivozanib hydrochloride  >  COc1cc2nccc(Oc3ccc(NC(=O)Nc4cc(C)on4)c(Cl)c3)c2cc1OC.Cl.O

# %% [markdown]
# ## Buscar proteina target, en este caso VEGF165

# %%
# Búsqueda de VEGF165 target
# %load_ext cudf.pandas
target = new_client.target
target_query = target.search('Neuropilin-1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references  \
# 0     [{'xref_id': 'O14786', 'xref_name': None, 'xre...
# 1                                                    []
# 2                                                    []
# 3     [{'xref_id': 'P30411', 'xref_name': None, 'xre...
# 4     [{'xref_id': 'P13497', 'xref_name': None, 'xre...
# ...                                                 ...
# 3898                                                 []
# 3899                                                 []
# 3900                                                 []
# 3901                                                 []
# 3902                                                 []
#
#                                              organism  \
# 0                                        Homo sapiens
# 1                                   Rattus norvegicus
# 2                                        Homo sapiens
# 3                                        Homo sapiens
# 4                                        Homo sapiens
# ...                                               ...
# 3898                                     Mus musculus
# 3899                                       Zika virus
# 3900  Severe acute respiratory syndrome coronavirus 2
# 3901    Yellow fever virus (strain 17D vaccine) (YFV)
# 3902                                Rattus norvegicus
#
#                                               pref_name  score  \
# 0                                          Neuropilin-1   21.0
# 1                                          Neuropilin-1   21.0
# 2                                          Neuropilin-2   17.0
# 3                                Bradykinin B2 receptor    8.0
# 4                          Bone morphogenetic protein 1    8.0
# ...                                                 ...    ...
# 3898  Inhibitor of nuclear factor kappa-B kinase sub...    0.0
# 3899                                 Genome polyprotein    0.0
# 3900                          Replicase polyprotein 1ab    0.0
# 3901                                 Genome polyprotein    0.0
# 3902                                   I-kappa-B kinase    0.0
#
#       species_group_flag target_chembl_id  \
# 0                  False       CHEMBL5174
# 1                  False    CHEMBL3309098
# 2                  False    CHEMBL4295667
# 3                  False       CHEMBL3157
# 4                  False       CHEMBL3898
# ...                  ...              ...
# 3898               False    CHEMBL4296092
# 3899               False    CHEMBL4523307
# 3900               False    CHEMBL4523582
# 3901               False    CHEMBL4523585
# 3902               False    CHEMBL4524001
#
#                                       target_components      target_type  \
# 0     [{'accession': 'O14786', 'component_descriptio...   SINGLE PROTEIN
# 1     [{'accession': 'Q9QWJ9', 'component_descriptio...   SINGLE PROTEIN
# 2     [{'accession': 'O60462', 'component_descriptio...   SINGLE PROTEIN
# 3     [{'accession': 'P30411', 'component_descriptio...   SINGLE PROTEIN
# 4     [{'accession': 'P13497', 'component_descriptio...   SINGLE PROTEIN
# ...                                                 ...              ...
# 3898  [{'accession': 'Q60680', 'component_descriptio...  PROTEIN COMPLEX
# 3899  [{'accession': 'Q32ZE1', 'component_descriptio...   SINGLE PROTEIN
# 3900  [{'accession': 'P0DTD1', 'component_descriptio...   SINGLE PROTEIN
# 3901  [{'accession': 'P03314', 'component_descriptio...   SINGLE PROTEIN
# 3902  [{'accession': 'Q9QY78', 'component_descriptio...  PROTEIN COMPLEX
#
#          tax_id
# 0        9606.0
# 1       10116.0
# 2        9606.0
# 3        9606.0
# 4        9606.0
# ...         ...
# 3898    10090.0
# 3899    64320.0
# 3900  2697049.0
# 3901    11090.0
# 3902    10116.0
#
# [3903 rows x 9 columns]

# %% [markdown]
# ## Selecionar y recuperar los datos de bioactividad para la proteina VEGF165

# %%
selected_target = 'CHEMBL5174'

# %%
# Filtrar el dataset para solo tener la fila donde el target_chembl_id sea igual a CHEMBL5174
selected_target_row = targets[targets['target_chembl_id'] == selected_target]
selected_target_row
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'O14786', 'xref_name': None, 'xre...  Homo sapiens
#
#       pref_name  score  species_group_flag target_chembl_id  \
# 0  Neuropilin-1   21.0               False       CHEMBL5174
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'O14786', 'component_descriptio...  SINGLE PROTEIN  9606.0

# %% [markdown]
# Aqui vamos a recuperar los datos de bioactividad para la proteina VEGF165

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')

# %%
pd.set_option('display.max_columns', None)
# Guardar response como dataframe
df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1747710                  []
# 1        None             None      1747711                  []
# 2        None             None      1747712                  []
# 3        None             None      1747713                  []
# 4        None             None      1747714                  []
#
#   assay_chembl_id                                assay_description assay_type  \
# 0    CHEMBL867991  Inhibition of VEGF165-NRP1 interaction by ELISA          B
# 1    CHEMBL867991  Inhibition of VEGF165-NRP1 interaction by ELISA          B
# 2    CHEMBL867991  Inhibition of VEGF165-NRP1 interaction by ELISA          B
# 3    CHEMBL867991  Inhibition of VEGF165-NRP1 interaction by ELISA          B
# 4    CHEMBL867991  Inhibition of VEGF165-NRP1 interaction by ELISA          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
# 3                    None                   None  BAO_0000190  BAO_0000357
# 4                    None                   None  BAO_0000190  BAO_0000357
#
#                bao_label                                   canonical_smiles  \
# 0  single protein format  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1  single protein format   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2  single protein format      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3  single protein format         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4  single protein format     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
#
#   data_validity_comment data_validity_description document_chembl_id  \
# 0                  None                      None      CHEMBL1146846
# 1                  None                      None      CHEMBL1146846
# 2                  None                      None      CHEMBL1146846
# 3                  None                      None      CHEMBL1146846
# 4                  None                      None      CHEMBL1146846
#
#        document_journal  document_year  \
# 0  Bioorg Med Chem Lett           2006
# 1  Bioorg Med Chem Lett           2006
# 2  Bioorg Med Chem Lett           2006
# 3  Bioorg Med Chem Lett           2006
# 4  Bioorg Med Chem Lett           2006
#
#                                    ligand_efficiency molecule_chembl_id  \
# 0  {'bei': '9.85', 'le': '0.18', 'lle': '-1.45', ...       CHEMBL212560
# 1  {'bei': '10.90', 'le': '0.20', 'lle': '-0.82',...       CHEMBL386641
# 2  {'bei': '11.42', 'le': '0.22', 'lle': '-1.36',...       CHEMBL425440
# 3  {'bei': '11.92', 'le': '0.23', 'lle': '-0.28',...       CHEMBL436932
# 4  {'bei': '11.35', 'le': '0.21', 'lle': '-2.27',...       CHEMBL213321
#
#   molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0               None              CHEMBL212560          4.10
# 1               None              CHEMBL386641          4.38
# 2               None              CHEMBL425440          4.10
# 3               None              CHEMBL436932          4.21
# 4               None              CHEMBL213321          4.22
#
#    potential_duplicate                                 qudt_units  record_id  \
# 0                    0  http://www.openphacts.org/units/Nanomolar     548320
# 1                    0  http://www.openphacts.org/units/Nanomolar     548321
# 2                    0  http://www.openphacts.org/units/Nanomolar     548327
# 3                    0  http://www.openphacts.org/units/Nanomolar     548328
# 4                    0  http://www.openphacts.org/units/Nanomolar     548329
#
#   relation  src_id  standard_flag standard_relation standard_text_value  \
# 0        =       1              1                 =                None
# 1        =       1              1                 =                None
# 2        =       1              1                 =                None
# 3        =       1              1                 =                None
# 4        =       1              1                 =                None
#
#   standard_type standard_units standard_upper_value standard_value  \
# 0          IC50             nM                 None        79000.0
# 1          IC50             nM                 None        42000.0
# 2          IC50             nM                 None        80000.0
# 3          IC50             nM                 None        62000.0
# 4          IC50             nM                 None        60000.0
#
#   target_chembl_id target_organism target_pref_name target_tax_id text_value  \
# 0       CHEMBL5174    Homo sapiens     Neuropilin-1          9606       None
# 1       CHEMBL5174    Homo sapiens     Neuropilin-1          9606       None
# 2       CHEMBL5174    Homo sapiens     Neuropilin-1          9606       None
# 3       CHEMBL5174    Homo sapiens     Neuropilin-1          9606       None
# 4       CHEMBL5174    Homo sapiens     Neuropilin-1          9606       None
#
#    toid  type units    uo_units upper_value value
# 0  None  IC50    uM  UO_0000065        None  79.0
# 1  None  IC50    uM  UO_0000065        None  42.0
# 2  None  IC50    uM  UO_0000065        None  80.0
# 3  None  IC50    uM  UO_0000065        None  62.0
# 4  None  IC50    uM  UO_0000065        None  60.0

# %%
records_df = len(df)
print(f'Number of records in the dataset: {records_df}')
# Out:
# Number of records in the dataset: 139

# %% [markdown]
# ## Descripción de columnas relevantes dentro del dataframe:
#
# * Standard Value: Es la potencia de la droga, mientras menor sea el valor más eficaz es, debido a que un mayor significa que se requiere de una mayor cantidad de droga para tener el mismo efecto

# %%
# Verificar que solo se cuente con registros de IC50
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
# Visualizar rango de valores de standard value
df.standard_value.unique()
# Out:
# array(['79000.0', '42000.0', '80000.0', '62000.0', '60000.0', '47000.0',
#        '9000.0', '4000.0', '3000.0', '2000.0', '95000.0', '22000.0',
#        '14000.0', '13000.0', '10000.0', '6000.0', '5000.0', '29000.0',
#        '43000.0', '19000.0', '18000.0', '30000.0', '17000.0', '52000.0',
#        '33000.0', '8000.0', '12000.0', '23000.0', '7000.0', '171000.0',
#        '92000.0', '9300.0', '609.0', '1600.0', '800.0', '4600.0',
#        '25118.86', '5400.0', '2900.0', '26000.0', '2951.21', '7762.47',
#        '7700.0', '5370.32', None, '120000.0', '187000.0', '181000.0',
#        '88000.0', '39000.0', '134000.0', '69000.0', '25000.0', '20900.0',
#        '21300.0', '48600.0', '7200.0', '16000.0', '100000.0', '8900.0',
#        '9200.0', '11700.0', '4300.0', '2300.0', '80500.0', '23400.0',
#        '16100.0', '18100.0', '50100.0', '84100.0', '831763.77',
#        '20892.96', '8912.51', '23442.29', '21379.62', '48977.88',
#        '14125.38', '7244.36', '15848.93', '9332.54', '10715.19',
#        '2884.03', '2238.72', '81283.05', '16218.1', '18197.01',
#        '50118.72', '11100.0', '41100.0', '19100.0', '41700.0', '34000.0'],
#       dtype=object)

# %% [markdown]
# # Guardar resultados en Google Drive

# %%
# Cargar Google Drive al notebook
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
locale.getpreferredencoding = lambda: "UTF-8"
# Crear carpeta dentro de google drive llamada data
! mkdir '/content/drive/My Drive/Colab Notebooks/data'
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/data’: File exists

# %%
# Subir el csv a la carpeta destino
df.to_csv('/content/drive/My Drive/Colab Notebooks/data/bioactivity_data.csv', index=False)

# %%
# Verificar que el archivo se encuentra en la carpeta destino
! ls -l '/content/drive/My Drive/Colab Notebooks/data'
# Out:
# total 311
# -rw------- 1 root root 15554 May  6 00:26 bioactivity_data_2class_pIC50.csv
# -rw------- 1 root root 74689 May  6 00:42 bioactivity_data.csv
# -rw------- 1 root root 10382 May  6 00:26 bioactivity_data_curated.csv
# -rw------- 1 root root  9354 May  6 00:26 bioactivity_data_preprocessed.csv
# -rw------- 1 root root   120 May  6 00:26 mannwhitneyu_LogP.csv
# -rw------- 1 root root   118 May  6 00:26 mannwhitneyu_MW.csv
# -rw------- 1 root root   129 May  6 00:26 mannwhitneyu_NumHAcceptors.csv
# -rw------- 1 root root   126 May  6 00:26 mannwhitneyu_NumHDonors.csv
# -rw------- 1 root root   121 May  6 00:26 mannwhitneyu_pIC50.csv
# -rw------- 1 root root 14327 May  6 00:26 plot_bioactivity_class.pdf
# -rw------- 1 root root 14125 May  6 00:26 plot_ic50.pdf
# -rw------- 1 root root 13693 May  6 00:26 plot_LogP.pdf
# -rw------- 1 root root 13101 May  6 00:26 plot_MW.pdf
# -rw------- 1 root root 25736 May  6 00:26 plot_MW_vs_LogP.pdf
# -rw------- 1 root root 14872 May  6 00:26 plot_NumHAcceptors.pdf
# -rw------- 1 root root 14355 May  6 00:26 plot_NumHDonors.pdf
# -rw------- 1 root root 92591 May  6 00:26 results.zip

# %% [markdown]
# Ver contenido de **bioactivity_data.csv**

# %%
! head '/content/drive/My Drive/Colab Notebooks/data/bioactivity_data.csv'
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,1747710,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '9.85', 'le': '0.18', 'lle': '-1.45', 'sei': '7.78'}",CHEMBL212560,,CHEMBL212560,4.10,0,http://www.openphacts.org/units/Nanomolar,548320,=,1,1,=,,IC50,nM,,79000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,79.0
# ,,1747711,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '10.90', 'le': '0.20', 'lle': '-0.82', 'sei': '7.89'}",CHEMBL386641,,CHEMBL386641,4.38,0,http://www.openphacts.org/units/Nanomolar,548321,=,1,1,=,,IC50,nM,,42000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,42.0
# ,,1747712,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '11.42', 'le': '0.22', 'lle': '-1.36', 'sei': '6.18'}",CHEMBL425440,,CHEMBL425440,4.10,0,http://www.openphacts.org/units/Nanomolar,548327,=,1,1,=,,IC50,nM,,80000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,80.0
# ,,1747713,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '11.92', 'le': '0.23', 'lle': '-0.28', 'sei': '9.68'}",CHEMBL436932,,CHEMBL436932,4.21,0,http://www.openphacts.org/units/Nanomolar,548328,=,1,1,=,,IC50,nM,,62000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,62.0
# ,,1747714,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '11.35', 'le': '0.21', 'lle': '-2.27', 'sei': '10.49'}",CHEMBL213321,,CHEMBL213321,4.22,0,http://www.openphacts.org/units/Nanomolar,548329,=,1,1,=,,IC50,nM,,60000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,60.0
# ,,1747715,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,CN(C)c1ccc(Nc2c(-c3ccccc3)c(C#N)c3cccc(Cl)n23)cc1,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '11.19', 'le': '0.21', 'lle': '-1.61', 'sei': '9.96'}",CHEMBL379547,,CHEMBL379547,4.33,0,http://www.openphacts.org/units/Nanomolar,548330,=,1,1,=,,IC50,nM,,47000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,47.0
# ,,1747716,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,COCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '15.49', 'le': '0.30', 'lle': '0.86', 'sei': '10.20'}",CHEMBL215998,,CHEMBL215998,5.05,0,http://www.openphacts.org/units/Nanomolar,548334,=,1,1,=,,IC50,nM,,9000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,9.0
# ,,1747717,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,CN(CCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12)Cc1ccccc1,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '13.01', 'le': '0.25', 'lle': '-0.28', 'sei': '12.42'}",CHEMBL411137,,CHEMBL411137,5.40,0,http://www.openphacts.org/units/Nanomolar,548335,=,1,1,=,,IC50,nM,,4000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,4.0
# ,,1747718,[],CHEMBL867991,Inhibition of VEGF165-NRP1 interaction by ELISA,B,,,BAO_0000190,BAO_0000357,single protein format,N#Cc1c(-c2ccccc2)c(NCCc2ccc(Cl)cc2)n2c(Cl)cccc12,,,CHEMBL1146846,Bioorg Med Chem Lett,2006,"{'bei': '13.28', 'le': '0.26', 'lle': '-1.04', 'sei': '13.42'}",CHEMBL386808,,CHEMBL386808,5.40,0,http://www.openphacts.org/units/Nanomolar,548336,=,1,1,=,,IC50,nM,,4000.0,CHEMBL5174,Homo sapiens,Neuropilin-1,9606,,,IC50,uM,UO_0000065,,4.0

# %% [markdown]
# ## Manejo de valores faltantes
# Dado que nos interesa conocer el standard value, los registros que no cuenten con esta información serán eliminados

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1747710                  []
# 1          None             None      1747711                  []
# 2          None             None      1747712                  []
# 3          None             None      1747713                  []
# 4          None             None      1747714                  []
# ..          ...              ...          ...                 ...
# 134        None             None     20628397                  []
# 135        None             None     20628398                  []
# 136        None             None     20628399                  []
# 137        None             None     20628400                  []
# 138        None             None     20628426                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 1      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 2      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 3      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 4      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# ..              ...                                                ...
# 134   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 135   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 136   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 137   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 138   CHEMBL4610309  Inhibition of biotinylated VEGFR1 binding to N...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 134          B                    None                   None  BAO_0000190
# 135          B                    None                   None  BAO_0000190
# 136          B                    None                   None  BAO_0000190
# 137          B                    None                   None  BAO_0000190
# 138          B                    None                   None  BAO_0000190
#
#       bao_format              bao_label  \
# 0    BAO_0000357  single protein format
# 1    BAO_0000357  single protein format
# 2    BAO_0000357  single protein format
# 3    BAO_0000357  single protein format
# 4    BAO_0000357  single protein format
# ..           ...                    ...
# 134  BAO_0000219      cell-based format
# 135  BAO_0000219      cell-based format
# 136  BAO_0000219      cell-based format
# 137  BAO_0000219      cell-based format
# 138  BAO_0000357  single protein format
#
#                                       canonical_smiles data_validity_comment  \
# 0    CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12                  None
# 1     CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12                  None
# 2        N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12                  None
# 3           CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12                  None
# 4       Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12                  None
# ..                                                 ...                   ...
# 134  N=C(N)NCCC[C@H](NC(=O)c1sccc1NS(=O)(=O)c1cccc2...                  None
# 135  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1                  None
# 136  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...                  None
# 137  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...                  None
# 138  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...                  None
#
#     data_validity_description document_chembl_id      document_journal  \
# 0                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 1                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 2                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 3                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 4                        None      CHEMBL1146846  Bioorg Med Chem Lett
# ..                        ...                ...                   ...
# 134                      None      CHEMBL4609981       Bioorg Med Chem
# 135                      None      CHEMBL4609981       Bioorg Med Chem
# 136                      None      CHEMBL4609981       Bioorg Med Chem
# 137                      None      CHEMBL4609981       Bioorg Med Chem
# 138                      None      CHEMBL4609981       Bioorg Med Chem
#
#      document_year                                  ligand_efficiency  \
# 0             2006  {'bei': '9.85', 'le': '0.18', 'lle': '-1.45', ...
# 1             2006  {'bei': '10.90', 'le': '0.20', 'lle': '-0.82',...
# 2             2006  {'bei': '11.42', 'le': '0.22', 'lle': '-1.36',...
# 3             2006  {'bei': '11.92', 'le': '0.23', 'lle': '-0.28',...
# 4             2006  {'bei': '11.35', 'le': '0.21', 'lle': '-2.27',...
# ..             ...                                                ...
# 134           2020  {'bei': '9.96', 'le': '0.21', 'lle': '3.95', '...
# 135           2020  {'bei': '10.05', 'le': '0.20', 'lle': '0.00', ...
# 136           2020  {'bei': '10.47', 'le': '0.21', 'lle': '0.02', ...
# 137           2020  {'bei': '9.68', 'le': '0.19', 'lle': '0.29', '...
# 138           2020  {'bei': '10.05', 'le': '0.19', 'lle': '0.03', ...
#
#     molecule_chembl_id molecule_pref_name parent_molecule_chembl_id  \
# 0         CHEMBL212560               None              CHEMBL212560
# 1         CHEMBL386641               None              CHEMBL386641
# 2         CHEMBL425440               None              CHEMBL425440
# 3         CHEMBL436932               None              CHEMBL436932
# 4         CHEMBL213321               None              CHEMBL213321
# ..                 ...                ...                       ...
# 134      CHEMBL1078974               None             CHEMBL1078974
# 135      CHEMBL4646334               None             CHEMBL4646334
# 136      CHEMBL4643884               None             CHEMBL4643884
# 137      CHEMBL4637483               None             CHEMBL4637483
# 138      CHEMBL3322197               None             CHEMBL3322197
#
#     pchembl_value  potential_duplicate  \
# 0            4.10                    0
# 1            4.38                    0
# 2            4.10                    0
# 3            4.21                    0
# 4            4.22                    0
# ..            ...                  ...
# 134          4.96                    0
# 135          4.39                    0
# 136          4.72                    0
# 137          4.38                    0
# 138          4.47                    0
#
#                                     qudt_units  record_id relation  src_id  \
# 0    http://www.openphacts.org/units/Nanomolar     548320        =       1
# 1    http://www.openphacts.org/units/Nanomolar     548321        =       1
# 2    http://www.openphacts.org/units/Nanomolar     548327        =       1
# 3    http://www.openphacts.org/units/Nanomolar     548328        =       1
# 4    http://www.openphacts.org/units/Nanomolar     548329        =       1
# ..                                         ...        ...      ...     ...
# 134  http://www.openphacts.org/units/Nanomolar    3471124        =       1
# 135  http://www.openphacts.org/units/Nanomolar    3471138        =       1
# 136  http://www.openphacts.org/units/Nanomolar    3471146        =       1
# 137  http://www.openphacts.org/units/Nanomolar    3471148        =       1
# 138  http://www.openphacts.org/units/Nanomolar    3471125        =       1
#
#      standard_flag standard_relation standard_text_value standard_type  \
# 0                1                 =                None          IC50
# 1                1                 =                None          IC50
# 2                1                 =                None          IC50
# 3                1                 =                None          IC50
# 4                1                 =                None          IC50
# ..             ...               ...                 ...           ...
# 134              1                 =                None          IC50
# 135              1                 =                None          IC50
# 136              1                 =                None          IC50
# 137              1                 =                None          IC50
# 138              1                 =                None          IC50
#
#     standard_units standard_upper_value standard_value target_chembl_id  \
# 0               nM                 None        79000.0       CHEMBL5174
# 1               nM                 None        42000.0       CHEMBL5174
# 2               nM                 None        80000.0       CHEMBL5174
# 3               nM                 None        62000.0       CHEMBL5174
# 4               nM                 None        60000.0       CHEMBL5174
# ..             ...                  ...            ...              ...
# 134             nM                 None        11100.0       CHEMBL5174
# 135             nM                 None        41100.0       CHEMBL5174
# 136             nM                 None        19100.0       CHEMBL5174
# 137             nM                 None        41700.0       CHEMBL5174
# 138             nM                 None        34000.0       CHEMBL5174
#
#     target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 1      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 2      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 3      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 4      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# ..              ...              ...           ...        ...   ...   ...
# 134    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 135    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 136    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 137    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 138    Homo sapiens     Neuropilin-1          9606       None  None  IC50
#
#     units    uo_units upper_value value
# 0      uM  UO_0000065        None  79.0
# 1      uM  UO_0000065        None  42.0
# 2      uM  UO_0000065        None  80.0
# 3      uM  UO_0000065        None  62.0
# 4      uM  UO_0000065        None  60.0
# ..    ...         ...         ...   ...
# 134    uM  UO_0000065        12.7  11.1
# 135    uM  UO_0000065        None  41.1
# 136    uM  UO_0000065        None  19.1
# 137    uM  UO_0000065        None  41.7
# 138    uM  UO_0000065        None  34.0
#
# [131 rows x 46 columns]

# %%
records_df2 = len(df2)
preserved_info = round((records_df2/records_df)*100,2)
print(f'Number of records in df2 {records_df2}, percentage of information preserved: {preserved_info}')
# Out:
# Number of records in df2 131, percentage of information preserved: 94.24

# %%
# Verificar la cantidad de registros de canonical smiles
canon_smiles_count = sum(df2.canonical_smiles.notnull())
canon_smiles_count
# Out:
# 131

# %%
# Verificar que la columna canonical_smiles cuente con valores unicos
unique_canon_smiles_count = len(df2.canonical_smiles.unique())
percentage_unique_canon_smiles = round(unique_canon_smiles_count/canon_smiles_count*100,2)
print(f'Number of unique canonical_smiles records in df2: {unique_canon_smiles_count}, percentage of unique records: {percentage_unique_canon_smiles}')
# Out:
# Number of unique canonical_smiles records in df2: 98, percentage of unique records: 74.81

# %% [markdown]
# ### Eliminar canonical_smiles duplicadas
#
# Una vez que notamos el porcentaje de entradas unicas, procedemos a eliminar los duplicados de la columna **canonical_smiles**

# %%
df2_unique_can_smiles = df2.drop_duplicates(['canonical_smiles'])
df2_unique_can_smiles
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1747710                  []
# 1          None             None      1747711                  []
# 2          None             None      1747712                  []
# 3          None             None      1747713                  []
# 4          None             None      1747714                  []
# ..          ...              ...          ...                 ...
# 112        None             None     19481290                  []
# 135        None             None     20628398                  []
# 136        None             None     20628399                  []
# 137        None             None     20628400                  []
# 138        None             None     20628426                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 1      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 2      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 3      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# 4      CHEMBL867991    Inhibition of VEGF165-NRP1 interaction by ELISA
# ..              ...                                                ...
# 112   CHEMBL4480618  Inhibition of human biotinylated VEGF-A165 bin...
# 135   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 136   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 137   CHEMBL4610306  Inhibition of recombinant human biotinylated V...
# 138   CHEMBL4610309  Inhibition of biotinylated VEGFR1 binding to N...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 112          B                    None                   None  BAO_0000190
# 135          B                    None                   None  BAO_0000190
# 136          B                    None                   None  BAO_0000190
# 137          B                    None                   None  BAO_0000190
# 138          B                    None                   None  BAO_0000190
#
#       bao_format              bao_label  \
# 0    BAO_0000357  single protein format
# 1    BAO_0000357  single protein format
# 2    BAO_0000357  single protein format
# 3    BAO_0000357  single protein format
# 4    BAO_0000357  single protein format
# ..           ...                    ...
# 112  BAO_0000357  single protein format
# 135  BAO_0000219      cell-based format
# 136  BAO_0000219      cell-based format
# 137  BAO_0000219      cell-based format
# 138  BAO_0000357  single protein format
#
#                                       canonical_smiles data_validity_comment  \
# 0    CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12                  None
# 1     CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12                  None
# 2        N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12                  None
# 3           CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12                  None
# 4       Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12                  None
# ..                                                 ...                   ...
# 112  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...                  None
# 135  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1                  None
# 136  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...                  None
# 137  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...                  None
# 138  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...                  None
#
#     data_validity_description document_chembl_id      document_journal  \
# 0                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 1                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 2                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 3                        None      CHEMBL1146846  Bioorg Med Chem Lett
# 4                        None      CHEMBL1146846  Bioorg Med Chem Lett
# ..                        ...                ...                   ...
# 112                      None      CHEMBL4480373           Medchemcomm
# 135                      None      CHEMBL4609981       Bioorg Med Chem
# 136                      None      CHEMBL4609981       Bioorg Med Chem
# 137                      None      CHEMBL4609981       Bioorg Med Chem
# 138                      None      CHEMBL4609981       Bioorg Med Chem
#
#      document_year                                  ligand_efficiency  \
# 0             2006  {'bei': '9.85', 'le': '0.18', 'lle': '-1.45', ...
# 1             2006  {'bei': '10.90', 'le': '0.20', 'lle': '-0.82',...
# 2             2006  {'bei': '11.42', 'le': '0.22', 'lle': '-1.36',...
# 3             2006  {'bei': '11.92', 'le': '0.23', 'lle': '-0.28',...
# 4             2006  {'bei': '11.35', 'le': '0.21', 'lle': '-2.27',...
# ..             ...                                                ...
# 112           2019  {'bei': '6.24', 'le': '0.12', 'lle': '6.82', '...
# 135           2020  {'bei': '10.05', 'le': '0.20', 'lle': '0.00', ...
# 136           2020  {'bei': '10.47', 'le': '0.21', 'lle': '0.02', ...
# 137           2020  {'bei': '9.68', 'le': '0.19', 'lle': '0.29', '...
# 138           2020  {'bei': '10.05', 'le': '0.19', 'lle': '0.03', ...
#
#     molecule_chembl_id molecule_pref_name parent_molecule_chembl_id  \
# 0         CHEMBL212560               None              CHEMBL212560
# 1         CHEMBL386641               None              CHEMBL386641
# 2         CHEMBL425440               None              CHEMBL425440
# 3         CHEMBL436932               None              CHEMBL436932
# 4         CHEMBL213321               None              CHEMBL213321
# ..                 ...                ...                       ...
# 112      CHEMBL4515173               None             CHEMBL4515173
# 135      CHEMBL4646334               None             CHEMBL4646334
# 136      CHEMBL4643884               None             CHEMBL4643884
# 137      CHEMBL4637483               None             CHEMBL4637483
# 138      CHEMBL3322197               None             CHEMBL3322197
#
#     pchembl_value  potential_duplicate  \
# 0            4.10                    0
# 1            4.38                    0
# 2            4.10                    0
# 3            4.21                    0
# 4            4.22                    0
# ..            ...                  ...
# 112          4.30                    0
# 135          4.39                    0
# 136          4.72                    0
# 137          4.38                    0
# 138          4.47                    0
#
#                                     qudt_units  record_id relation  src_id  \
# 0    http://www.openphacts.org/units/Nanomolar     548320        =       1
# 1    http://www.openphacts.org/units/Nanomolar     548321        =       1
# 2    http://www.openphacts.org/units/Nanomolar     548327        =       1
# 3    http://www.openphacts.org/units/Nanomolar     548328        =       1
# 4    http://www.openphacts.org/units/Nanomolar     548329        =       1
# ..                                         ...        ...      ...     ...
# 112  http://www.openphacts.org/units/Nanomolar    3257738        =       1
# 135  http://www.openphacts.org/units/Nanomolar    3471138        =       1
# 136  http://www.openphacts.org/units/Nanomolar    3471146        =       1
# 137  http://www.openphacts.org/units/Nanomolar    3471148        =       1
# 138  http://www.openphacts.org/units/Nanomolar    3471125        =       1
#
#      standard_flag standard_relation standard_text_value standard_type  \
# 0                1                 =                None          IC50
# 1                1                 =                None          IC50
# 2                1                 =                None          IC50
# 3                1                 =                None          IC50
# 4                1                 =                None          IC50
# ..             ...               ...                 ...           ...
# 112              1                 =                None          IC50
# 135              1                 =                None          IC50
# 136              1                 =                None          IC50
# 137              1                 =                None          IC50
# 138              1                 =                None          IC50
#
#     standard_units standard_upper_value standard_value target_chembl_id  \
# 0               nM                 None        79000.0       CHEMBL5174
# 1               nM                 None        42000.0       CHEMBL5174
# 2               nM                 None        80000.0       CHEMBL5174
# 3               nM                 None        62000.0       CHEMBL5174
# 4               nM                 None        60000.0       CHEMBL5174
# ..             ...                  ...            ...              ...
# 112             nM                 None        50100.0       CHEMBL5174
# 135             nM                 None        41100.0       CHEMBL5174
# 136             nM                 None        19100.0       CHEMBL5174
# 137             nM                 None        41700.0       CHEMBL5174
# 138             nM                 None        34000.0       CHEMBL5174
#
#     target_organism target_pref_name target_tax_id text_value  toid  type  \
# 0      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 1      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 2      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 3      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 4      Homo sapiens     Neuropilin-1          9606       None  None  IC50
# ..              ...              ...           ...        ...   ...   ...
# 112    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 135    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 136    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 137    Homo sapiens     Neuropilin-1          9606       None  None  IC50
# 138    Homo sapiens     Neuropilin-1          9606       None  None  IC50
#
#     units    uo_units upper_value value
# 0      uM  UO_0000065        None  79.0
# 1      uM  UO_0000065        None  42.0
# 2      uM  UO_0000065        None  80.0
# 3      uM  UO_0000065        None  62.0
# 4      uM  UO_0000065        None  60.0
# ..    ...         ...         ...   ...
# 112    uM  UO_0000065        None  50.1
# 135    uM  UO_0000065        None  41.1
# 136    uM  UO_0000065        None  19.1
# 137    uM  UO_0000065        None  41.7
# 138    uM  UO_0000065        None  34.0
#
# [98 rows x 46 columns]

# %% [markdown]
# ## Preprocesamiento de datos de bioactividad
#
# ### Análisis de correlación cuantitativos y gráficos
#
# Análisis de correlación de variables numéricas a través del método de **Pearson**
#
# Para ello observamos el número de columnas que tenemos y notamos de qué tipo son cada una:

# %%
df2_unique_can_smiles.loc[:, 'pchembl_value'] = df2_unique_can_smiles['pchembl_value'].astype(float)
df2_unique_can_smiles.loc[:, 'standard_value'] = df2_unique_can_smiles['standard_value'].astype(float)
df2_unique_can_smiles.loc[:, 'value'] = df2_unique_can_smiles['value'].astype(float)

df2_unique_can_smiles = df2_unique_can_smiles.astype({'pchembl_value': 'float64', 'standard_value': 'float64', 'value': 'float64'})

# %%
# Un breve conteo de Nulos
# Esto nos ayudará para la ingeniería de datos
null_counts = df2_unique_can_smiles.isnull().sum()
print(null_counts)
# Out:
# action_type                  98
# activity_comment             98
# activity_id                   0
# activity_properties           0
# assay_chembl_id               0
# assay_description             0
# assay_type                    0
# assay_variant_accession      98
# assay_variant_mutation       98
# bao_endpoint                  0
# bao_format                    0
# bao_label                     0
# canonical_smiles              0
# data_validity_comment        93
# data_validity_description    93
# document_chembl_id            0
# document_journal              0
# document_year                 0
# ligand_efficiency             7
# molecule_chembl_id            0
# molecule_pref_name           98
# parent_molecule_chembl_id     0
# pchembl_value                 7
# potential_duplicate           0
# qudt_units                    0
# record_id                     0
# relation                      0
# src_id                        0
# standard_flag                 0
# standard_relation             0
# standard_text_value          98
# standard_type                 0
# standard_units                0
# standard_upper_value         98
# standard_value                0
# target_chembl_id              0
# target_organism               0
# target_pref_name              0
# target_tax_id                 0
# text_value                   98
# toid                         98
# type                          0
# units                         2
# uo_units                      0
# upper_value                  98
# value                         0
# dtype: int64

# %%
# Desplegar el total de columnas del DF
columns_names = df2_unique_can_smiles.columns.values
columns_names
# Out:
# array(['action_type', 'activity_comment', 'activity_id',
#        'activity_properties', 'assay_chembl_id', 'assay_description',
#        'assay_type', 'assay_variant_accession', 'assay_variant_mutation',
#        'bao_endpoint', 'bao_format', 'bao_label', 'canonical_smiles',
#        'data_validity_comment', 'data_validity_description',
#        'document_chembl_id', 'document_journal', 'document_year',
#        'ligand_efficiency', 'molecule_chembl_id', 'molecule_pref_name',
#        'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation',
#        'src_id', 'standard_flag', 'standard_relation',
#        'standard_text_value', 'standard_type', 'standard_units',
#        'standard_upper_value', 'standard_value', 'target_chembl_id',
#        'target_organism', 'target_pref_name', 'target_tax_id',
#        'text_value', 'toid', 'type', 'units', 'uo_units', 'upper_value',
#        'value'], dtype=object)

# %%
df2_unique_can_smiles.dtypes
# Out:
# action_type                   object
# activity_comment              object
# activity_id                    int64
# activity_properties           object
# assay_chembl_id               object
# assay_description             object
# assay_type                    object
# assay_variant_accession       object
# assay_variant_mutation        object
# bao_endpoint                  object
# bao_format                    object
# bao_label                     object
# canonical_smiles              object
# data_validity_comment         object
# data_validity_description     object
# document_chembl_id            object
# document_journal              object
# document_year                  int64
# ligand_efficiency             object
# molecule_chembl_id            object
# molecule_pref_name            object
# parent_molecule_chembl_id     object
# pchembl_value                float64
# potential_duplicate            int64
# qudt_units                    object
# record_id                      int64
# relation                      object
# src_id                         int64
# standard_flag                  int64
# standard_relation             object
# standard_text_value           object
# standard_type                 object
# standard_units                object
# standard_upper_value          object
# standard_value               float64
# target_chembl_id              object
# target_organism               object
# target_pref_name              object
# target_tax_id                 object
# text_value                    object
# toid                          object
# type                          object
# units                         object
# uo_units                      object
# upper_value                   object
# value                        float64
# dtype: object

# %%
# Calcular la matriz de correlación
correlation_matrix = df2_unique_can_smiles.corr(numeric_only=True, method='pearson')

# Visualizar la matriz de correlación como un mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Mapa de calor de la matriz de correlación')
plt.show()

# %% [markdown]
# Análisis de correlación de variables numéricas a través del método de **Spearman**

# %%
# Calcular la matriz de correlación
correlation_matrix = df2_unique_can_smiles.corr(numeric_only=True, method='spearman')

# Visualizar la matriz de correlación como un mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Mapa de calor de la matriz de correlación')
plt.show()

# %% [markdown]
# Análisis de correlación de variables numéricas a través del método de **kendall**

# %%
# Calcular la matriz de correlación
correlation_matrix = df2_unique_can_smiles.corr(numeric_only=True, method='kendall')

# Visualizar la matriz de correlación como un mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Mapa de calor de la matriz de correlación')
plt.show()

# %% [markdown]
# A modo de **conclusión**, podemos ver que las únicas columnas numéricas están asociadas a años, e identificadores. Estos datos no son de alta importancia para nuestro modelo de IA. La justificación y selección de columnas se detalla a continuación.

# %% [markdown]
# ### Combinar 3 columnas (molecule_chembl_id,canonical_smiles,standard_value) y bioactivity_class en un DataFrame
#
# * **molecule_chembl_id**: Esta columna contiene identificadores únicos para las moléculas en el conjunto de datos. Es crucial si estás trabajando con un conjunto de datos que involucra múltiples moléculas y necesitas distinguirlas y realizar operaciones específicas basadas en su identificación.
#
# * **canonical_smiles**: El SMILES canónico es una representación única y estandarizada de la estructura química de una molécula. Esta columna es importante cuando se realizan análisis químicos o comparacion de estructuras moleculares entre diferentes moléculas dentro del conjunto de datos.
#
# * **standard_value**: Esta columna contiene valores numéricos que representan medidas estándar asociadas con las moléculas, como la actividad biológica de un compuesto (por ejemplo, la concentración inhibidora 50 (IC50) en ensayos biológicos). Es una columna crucial si estás interesado en analizar la actividad biológica de las moléculas o realizar comparaciones cuantitativas entre ellas.
#
# Al seleccionar estas columnas específicas, estamos enfocando tu análisis en la identificación de las moléculas, sus estructuras químicas y las medidas estándar asociadas con su actividad biológica.
#
# La Bioactividad será calculada/etiquetada en los siguientes pasos a través de un umbral.

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_unique_can_smiles[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL212560  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1         CHEMBL386641   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2         CHEMBL425440      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3         CHEMBL436932         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4         CHEMBL213321     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# ..                 ...                                                ...
# 112      CHEMBL4515173  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...
# 135      CHEMBL4646334  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1
# 136      CHEMBL4643884  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...
# 137      CHEMBL4637483  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...
# 138      CHEMBL3322197  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...
#
#      standard_value
# 0           79000.0
# 1           42000.0
# 2           80000.0
# 3           62000.0
# 4           60000.0
# ..              ...
# 112         50100.0
# 135         41100.0
# 136         19100.0
# 137         41700.0
# 138         34000.0
#
# [98 rows x 3 columns]

# %% [markdown]
# Guardar resultados en un archivo CSV

# %%
# Subir el csv a la carpeta destino
df3.to_csv('/content/drive/My Drive/Colab Notebooks/data/bioactivity_data_preprocessed.csv', index=False)

# %%
# Verificar cambios
! ls '/content/drive/My Drive/Colab Notebooks/data/'
# Out:
# bioactivity_data_2class_pIC50.csv  mannwhitneyu_NumHAcceptors.csv  plot_MW.pdf
# bioactivity_data.csv		   mannwhitneyu_NumHDonors.csv	   plot_MW_vs_LogP.pdf
# bioactivity_data_curated.csv	   mannwhitneyu_pIC50.csv	   plot_NumHAcceptors.pdf
# bioactivity_data_preprocessed.csv  plot_bioactivity_class.pdf	   plot_NumHDonors.pdf
# mannwhitneyu_LogP.csv		   plot_ic50.pdf		   results.zip
# mannwhitneyu_MW.csv		   plot_LogP.pdf

# %% [markdown]
# ### Etiquetado de componentes
# Los datos de bioactividad estan en la unidad IC50. Compuestos con menos de 1000 nM será considerados como **activos** mientras aquellos que sean mayores a 10,000 nM serán considerados como **inactivos**. Todos los valores que caen dentro de 1,000 y 10,000 nM serán clasificados como **intermedios**.

# %%
# Leer csv con datos preprocesados
df4 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
# Concatenar lista generada como una serie de pandas y agregarla al df
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL212560  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1        CHEMBL386641   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2        CHEMBL425440      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3        CHEMBL436932         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4        CHEMBL213321     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# ..                ...                                                ...
# 93      CHEMBL4515173  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...
# 94      CHEMBL4646334  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1
# 95      CHEMBL4643884  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...
# 96      CHEMBL4637483  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...
# 97      CHEMBL3322197  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...
#
#     standard_value     class
# 0          79000.0  inactive
# 1          42000.0  inactive
# 2          80000.0  inactive
# 3          62000.0  inactive
# 4          60000.0  inactive
# ..             ...       ...
# 93         50100.0  inactive
# 94         41100.0  inactive
# 95         19100.0  inactive
# 96         41700.0  inactive
# 97         34000.0  inactive
#
# [98 rows x 4 columns]

# %% [markdown]
# Guardad dataframe como archivo csv

# %%
# Subir el csv a la carpeta destino
df5.to_csv('/content/drive/My Drive/Colab Notebooks/data/bioactivity_data_curated.csv', index=False)

# %% [markdown]
# ## Cargar datos de bioactividad

# %%
# Leer el archivo con los datos curados
df6 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/bioactivity_data_curated.csv')
df6
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL212560  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1        CHEMBL386641   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2        CHEMBL425440      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3        CHEMBL436932         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4        CHEMBL213321     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# ..                ...                                                ...
# 93      CHEMBL4515173  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...
# 94      CHEMBL4646334  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1
# 95      CHEMBL4643884  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...
# 96      CHEMBL4637483  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...
# 97      CHEMBL3322197  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...
#
#     standard_value     class
# 0          79000.0  inactive
# 1          42000.0  inactive
# 2          80000.0  inactive
# 3          62000.0  inactive
# 4          60000.0  inactive
# ..             ...       ...
# 93         50100.0  inactive
# 94         41100.0  inactive
# 95         19100.0  inactive
# 96         41700.0  inactive
# 97         34000.0  inactive
#
# [98 rows x 4 columns]

# %% [markdown]
# ## Calcular descriptores Lipinski
#
# ### Regla de Lipinski
#
#
# La regla de Lipinski establece los siguientes criterios para evaluar la idoneidad de una molécula como candidato a fármaco:
#
# 1. **Peso molecular (MW):** MW < 500
# 2. **LogP (coeficiente de partición octanol-agua):** LogP < 5
# 3. **Número de donantes de hidrógeno (HBD):** HBD < 5
# 4. **Número de aceptores de hidrógeno (HBA):** HBA < 10

# %%
def lipinski(smiles, verbose=False):

  moldata = []
  for element in smiles:
    mol = Chem.MolFromSmiles(element)
    moldata.append(mol)

  baseData = np.arange(1,1)
  i = 0
  for mol in moldata:

    desc_MolWt = Descriptors.MolWt(mol)
    desc_MolLogP = Descriptors.MolLogP(mol)
    desc_NumHDonors = Lipinski.NumHDonors(mol)
    desc_NumAcceptors = Lipinski.NumHAcceptors(mol)

    row = np.array([desc_MolWt,
                    desc_MolLogP,
                    desc_NumHDonors,
                    desc_NumAcceptors])

    if i==0:
      baseData = row
    else:
      baseData = np.vstack([baseData, row])
    i = i+1

  columNames = ['MW','LogP','NumHDonors','NumHAcceptors']
  descriptors = pd.DataFrame(data=baseData, columns = columNames)

  return descriptors

# %%
df_lipinski = lipinski(df6.canonical_smiles)

# %% [markdown]
# ## Combinar DataFrames

# %%
# Visualizar el dataframe con los descriptores calculados
df_lipinski
# Out:
#          MW     LogP  NumHDonors  NumHAcceptors
# 0   416.569  5.55308         1.0            5.0
# 1   401.558  5.19608         2.0            5.0
# 2   358.832  5.45718         2.0            4.0
# 3   352.869  4.49498         1.0            4.0
# 4   371.871  6.49182         1.0            3.0
# ..      ...      ...         ...            ...
# 93  688.835 -2.51836        12.0            9.0
# 94  436.566  4.38742         1.0            8.0
# 95  450.593  4.69584         1.0            8.0
# 96  452.565  4.09302         2.0            9.0
# 97  444.516  4.43632         3.0            5.0
#
# [98 rows x 4 columns]

# %%
combined_df = pd.concat([df6, df_lipinski], axis=1)
combined_df
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL212560  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1        CHEMBL386641   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2        CHEMBL425440      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3        CHEMBL436932         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4        CHEMBL213321     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# ..                ...                                                ...
# 93      CHEMBL4515173  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...
# 94      CHEMBL4646334  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1
# 95      CHEMBL4643884  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...
# 96      CHEMBL4637483  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...
# 97      CHEMBL3322197  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...
#
#     standard_value     class       MW     LogP  NumHDonors  NumHAcceptors
# 0          79000.0  inactive  416.569  5.55308         1.0            5.0
# 1          42000.0  inactive  401.558  5.19608         2.0            5.0
# 2          80000.0  inactive  358.832  5.45718         2.0            4.0
# 3          62000.0  inactive  352.869  4.49498         1.0            4.0
# 4          60000.0  inactive  371.871  6.49182         1.0            3.0
# ..             ...       ...      ...      ...         ...            ...
# 93         50100.0  inactive  688.835 -2.51836        12.0            9.0
# 94         41100.0  inactive  436.566  4.38742         1.0            8.0
# 95         19100.0  inactive  450.593  4.69584         1.0            8.0
# 96         41700.0  inactive  452.565  4.09302         2.0            9.0
# 97         34000.0  inactive  444.516  4.43632         3.0            5.0
#
# [98 rows x 8 columns]

# %% [markdown]
# ## Convertir IC50 a pIC50
#
# Para contar con datos más uniformes, se convirtió **IC50** a su escala logaritmica negativa, lo cual esencialemnte es ${-\log_{10}(IC_{50})}$
#
# Se definió una función **pIC50** la cual aceptará un dataframe como entrada y hará lo siguiente:
#
# * Tomar los valores de IC50 de la columna **standard_value** y los convertirá de nM a M mediante la multiplicación del valor por ${10^{-9}}$.
# * Tomar el valor molar y aplicar ${-\log_{10}}$
# * Borrar la columna de **standard_value** y crear una nueva columna llamada **pIC50**.

# %%
def pIC50(input):
  pIC50 = []
  for i in input['standard_value_norm']:
    molar = i*(10**-9) # Convierte nM a M
    pIC50.append(-np.log10(molar))

  input['pIC50'] = pIC50
  x = input.drop(columns='standard_value_norm')

  return x

# %% [markdown]
# Los valores mayores a 100,000,000 se quedarán en 100,000,000, de no hacerlo así los valores logaritmicos negativos se convertirán en negativos.

# %%
combined_df.standard_value.describe()
# Out:
# count        98.000000
# mean      29928.472755
# std       39451.145929
# min         609.000000
# 25%        5550.000000
# 50%       14000.000000
# 75%       37750.000000
# max      187000.000000
# Name: standard_value, dtype: float64

# %% [markdown]
# En este caso no es necesario pero se debe implementar esa lógica para evitar cualquier tipo de problema en el futuro.

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop(columns='standard_value')

    return x

# %% [markdown]
# Primero aplicaremos la función **norm_value** para que los valores dentro de la columna **standard_value** sean normalizados.

# %%
df_norm = norm_value(combined_df)

# %% [markdown]
# El siguiente paso es convertir la columna IC50 a pIC50

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL212560  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1        CHEMBL386641   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2        CHEMBL425440      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3        CHEMBL436932         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4        CHEMBL213321     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# ..                ...                                                ...
# 93      CHEMBL4515173  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...
# 94      CHEMBL4646334  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1
# 95      CHEMBL4643884  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...
# 96      CHEMBL4637483  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...
# 97      CHEMBL3322197  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...
#
#        class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0   inactive  416.569  5.55308         1.0            5.0  4.102373
# 1   inactive  401.558  5.19608         2.0            5.0  4.376751
# 2   inactive  358.832  5.45718         2.0            4.0  4.096910
# 3   inactive  352.869  4.49498         1.0            4.0  4.207608
# 4   inactive  371.871  6.49182         1.0            3.0  4.221849
# ..       ...      ...      ...         ...            ...       ...
# 93  inactive  688.835 -2.51836        12.0            9.0  4.300162
# 94  inactive  436.566  4.38742         1.0            8.0  4.386158
# 95  inactive  450.593  4.69584         1.0            8.0  4.718967
# 96  inactive  452.565  4.09302         2.0            9.0  4.379864
# 97  inactive  444.516  4.43632         3.0            5.0  4.468521
#
# [98 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    98.000000
# mean      4.846317
# std       0.555514
# min       3.728158
# 25%       4.423832
# 50%       4.853872
# 75%       5.256167
# max       6.215383
# Name: pIC50, dtype: float64

# %% [markdown]
# ## Eliminar la clase bioactiva intermedia
#
# Cuando eliminamos una clase bioactiva intermedia durante el análisis de datos del CHEMBL para la proteína VEGF165, estamos simplificando el análisis, enfoncanonos en resultados relevantes, optimizamos recursos y mejoramos la precisión de los resultados obtenidos.

# %%
df_2classes = df_final[df_final['class'] != 'intermediate']
df_2classes
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL212560  CN(C)CCCOc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 1        CHEMBL386641   CN(C)CCNc1cccc2c(C#N)c(-c3ccccc3)c(NC3CCCCC3)n12
# 2        CHEMBL425440      N#Cc1c(-c2ccccc2)c(Nc2cccc(N)c2)n2c(Cl)cccc12
# 3        CHEMBL436932         CN(C)CCCNc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# 4        CHEMBL213321     Cc1cccc(C)c1Nc1c(-c2ccccc2)c(C#N)c2cccc(Cl)n12
# ..                ...                                                ...
# 93      CHEMBL4515173  C[C@H](NC(=O)[C@@H]1Cc2ccccc2CN1C(=O)[C@@H](N)...
# 94      CHEMBL4646334  CCc1nnc(NC(=O)CSc2nnc(-c3ccccc3)n2-c2cccc(C)c2)s1
# 95      CHEMBL4643884  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(C)cc3)n2-c2cccc(C...
# 96      CHEMBL4637483  CCc1nnc(NC(=O)CSc2nnc(-c3ccc(O)cc3)n2-c2cccc(C...
# 97      CHEMBL3322197  Cc1ccc(-c2nc3ccccc3[nH]2)cc1NC(=S)NC(=O)c1ccc2...
#
#        class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0   inactive  416.569  5.55308         1.0            5.0  4.102373
# 1   inactive  401.558  5.19608         2.0            5.0  4.376751
# 2   inactive  358.832  5.45718         2.0            4.0  4.096910
# 3   inactive  352.869  4.49498         1.0            4.0  4.207608
# 4   inactive  371.871  6.49182         1.0            3.0  4.221849
# ..       ...      ...      ...         ...            ...       ...
# 93  inactive  688.835 -2.51836        12.0            9.0  4.300162
# 94  inactive  436.566  4.38742         1.0            8.0  4.386158
# 95  inactive  450.593  4.69584         1.0            8.0  4.718967
# 96  inactive  452.565  4.09302         2.0            9.0  4.379864
# 97  inactive  444.516  4.43632         3.0            5.0  4.468521
#
# [62 rows x 8 columns]

# %%
# Guardar dataframe en archivo csv
df_final.to_csv('/content/drive/My Drive/Colab Notebooks/data/bioactivity_data_2class_pIC50.csv', index=False)

# %% [markdown]
# ## Análisis exploratorio de los datos (Análisis del Espacio Químico) mediante descriptores Lipinski

# %% [markdown]
# ### Distribución de las dos clases de bioactividad

# %%
sns.set(style='ticks')
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2classes, edgecolor='black', hue='class')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_bioactivity_class.pdf')

# %% [markdown]
# ### Gráfica de dispersión

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2classes, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_MW_vs_LogP.pdf')

# %% [markdown]
# ### Diagrama de caja
# #### Valor de pIC50

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2classes, hue = 'class')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_ic50.pdf')

# %% [markdown]
# ##### Análisis estadístico
# **Prueba U Mann-Whitney**

# %%
def mannwhitney(descriptor, verbose=False):

  # Generador de semilla aleatoria
    seed(1)

  # Activos e inactivos
    selection = [descriptor, 'class']
    df = df_2classes[selection]
    active = df[df['class'] == 'active']
    active = active[descriptor]

    selection = [descriptor, 'class']
    df = df_2classes[selection]
    inactive = df[df['class'] == 'inactive']
    inactive = inactive[descriptor]

  # Comparar muestras
    stat, p = mannwhitneyu(active, inactive)

  # Interpretar
    alpha = 0.05
    if p > alpha:
      interpretation = 'Same distribution (fail to reject H0)'
    else:
      interpretation = 'Different distribution (reject H0)'

    results = pd.DataFrame({'Descriptor':descriptor,
                            'Statistics':stat,
                            'p':p,
                            'alpha':alpha,
                            'Interpretation':interpretation}, index=[0])
    filename = 'mannwhitneyu_' + descriptor + '.csv'
    results.to_csv(f'/content/drive/My Drive/Colab Notebooks/data/{filename}')

    return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics         p  alpha                      Interpretation
# 0      pIC50       120.0  0.017719   0.05  Different distribution (reject H0)

# %% [markdown]
# #### MW

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2classes, hue = 'class')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0         MW        76.0  0.536856   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### LogP

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2classes, hue = 'class')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_LogP.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0       LogP        48.0  0.646809   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### NumHDonors

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2classes, hue = 'class')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics         p  alpha  \
# 0  NumHDonors        73.0  0.615769   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### NumHAcceptors

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2classes)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('/content/drive/My Drive/Colab Notebooks/data/plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics        p  alpha  \
# 0  NumHAcceptors        63.0  0.91994   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #### Guardar en un archivo comprimido los archivos generados

# %%
# Guardar archivos en un archivo zip
# !zip -r /content/drive/My\ Drive/Colab\ Notebooks/data/results.zip /content/drive/My\ Drive/Colab\ Notebooks/data/*.pdf /content/drive/My\ Drive/Colab\ Notebooks/data/*.csv
# Out:
# updating: content/drive/My Drive/Colab Notebooks/data/plot_bioactivity_class.pdf (deflated 37%)
# updating: content/drive/My Drive/Colab Notebooks/data/plot_ic50.pdf (deflated 38%)
# updating: content/drive/My Drive/Colab Notebooks/data/plot_LogP.pdf (deflated 38%)
# updating: content/drive/My Drive/Colab Notebooks/data/plot_MW.pdf (deflated 38%)
# updating: content/drive/My Drive/Colab Notebooks/data/plot_MW_vs_LogP.pdf (deflated 19%)
# updating: content/drive/My Drive/Colab Notebooks/data/plot_NumHAcceptors.pdf (deflated 37%)
# updating: content/drive/My Drive/Colab Notebooks/data/plot_NumHDonors.pdf (deflated 37%)
# updating: content/drive/My Drive/Colab Notebooks/data/bioactivity_data_2class_pIC50.csv (deflated 77%)
# updating: content/drive/My Drive/Colab Notebooks/data/bioactivity_data.csv (deflated 90%)
# updating: content/drive/My Drive/Colab Notebooks/data/bioactivity_data_curated.csv (deflated 83%)
# updating: content/drive/My Drive/Colab Notebooks/data/bioactivity_data_preprocessed.csv (deflated 82%)
# updating: content/drive/My Drive/Colab Notebooks/data/mannwhitneyu_LogP.csv (deflated 8%)
# updating: content/drive/My Drive/Colab Notebooks/data/mannwhitneyu_MW.csv (deflated 8%)
# updating: content/drive/My Drive/Colab Notebooks/data/mannwhitneyu_NumHAcceptors.csv (deflated 11%)
# updating: content/drive/My Drive/Colab Notebooks/data/mannwhitneyu_NumHDonors.csv (deflated 10%)
# updating: content/drive/My Drive/Colab Notebooks/data/mannwhitneyu_pIC50.csv (deflated 9%)

# %%
# Verificar cambios
! ls '/content/drive/My Drive/Colab Notebooks/data/'
# Out:
# bioactivity_data_2class_pIC50.csv  mannwhitneyu_NumHAcceptors.csv  plot_MW.pdf
# bioactivity_data.csv		   mannwhitneyu_NumHDonors.csv	   plot_MW_vs_LogP.pdf
# bioactivity_data_curated.csv	   mannwhitneyu_pIC50.csv	   plot_NumHAcceptors.pdf
# bioactivity_data_preprocessed.csv  plot_bioactivity_class.pdf	   plot_NumHDonors.pdf
# mannwhitneyu_LogP.csv		   plot_ic50.pdf		   results.zip
# mannwhitneyu_MW.csv		   plot_LogP.pdf
